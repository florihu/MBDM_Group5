# %%
from ema_workbench import (
    Model,
    Policy,
    ema_logging,
    SequentialEvaluator,
    MultiprocessingEvaluator,
    perform_experiments,
    Samplers,
    Scenario
)
import numpy as np
import pandas as pd
import copy
from problem_formulation import get_model_for_problem_formulation, sum_over, sum_over_time


dike_model, planning_steps = get_model_for_problem_formulation(2)

uncertainties = copy.deepcopy(dike_model.uncertainties)

levers = copy.deepcopy(dike_model.levers)

outcome_names = []
for outcome in dike_model.outcomes:
    outcome_names.append(outcome.name)

print(outcome_names)
# Out:
# ['Expected Annual Damage', 'Dike Investment Costs', 'RfR Investment Costs', 'Evacuation Costs', 'Expected Number of Deaths', 'Min Water Level', 'Max Water Level']

# %%
policies_to_evaluate = [
 Policy('1412',**{'0_RfR 0': 0, '0_RfR 1': 0, '0_RfR 2': 0, '1_RfR 0': 0, '1_RfR 1': 0, '1_RfR 2': 0, '2_RfR 0': 0, '2_RfR 1': 1, '2_RfR 2': 0, '3_RfR 0': 0, '3_RfR 1': 0, '3_RfR 2': 0, '4_RfR 0': 0, '4_RfR 1': 0, '4_RfR 2': 0, 'EWS_DaysToThreat': 2, 'A.1_DikeIncrease 0': 5, 'A.1_DikeIncrease 1': 0, 'A.1_DikeIncrease 2': 0, 'A.2_DikeIncrease 0': 2, 'A.2_DikeIncrease 1': 0, 'A.2_DikeIncrease 2': 0, 'A.3_DikeIncrease 0': 2, 'A.3_DikeIncrease 1': 0, 'A.3_DikeIncrease 2': 0, 'A.4_DikeIncrease 0': 2, 'A.4_DikeIncrease 1': 0, 'A.4_DikeIncrease 2': 1, 'A.5_DikeIncrease 0': 3, 'A.5_DikeIncrease 1': 0, 'A.5_DikeIncrease 2': 0})
]

# %% [markdown]
# policy
# 1412    0.263193
# 1662    0.419249
# 1380    0.431670
# 911     0.431670

# %%
scenarios = 1000

with MultiprocessingEvaluator(dike_model) as evaluator:
    results = evaluator.perform_experiments(scenarios, policies_to_evaluate, uncertainty_sampling=Samplers.SOBOL)



experiments, outcomes = results

outcomes_df= pd.DataFrame.from_dict(outcomes)
experiments_df= pd.DataFrame.from_dict(outcomes)
# safe outcomes to csv / json
outcomes_df.to_csv('GSA_final_outcomes')
experiments_df.to_csv('GSA_final_experiments')
# Out:
# C:\Users\admin\Documents\GitHub\MBDM_Group5\venv\Lib\site-packages\scipy\stats\_qmc.py:763: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# 100%|██████████████████████████████████| 40000/40000 [2:12:37<00:00,  5.03it/s]

# %%
from ema_workbench.em_framework.salib_samplers import get_SALib_problem
from SALib.analyze import sobol

problem = get_SALib_problem(uncertainties)

results_Si =dict()

for item in outcomes_df.columns:
    results_Si[item] = sobol.analyze(problem, outcomes[item], calc_second_order=True, print_to_console=True, parallel=True)
# Out:
#                                    ST   ST_conf
# A.0_ID flood wave shape  8.676805e-03  0.002602
# A.1_Bmax                 5.586621e-03  0.010000
# A.1_Brate                3.173144e-05  0.000038
# A.1_pfail                4.717178e-01  0.105244
# A.2_Bmax                 2.370083e-03  0.003901
# A.2_Brate                3.875086e-05  0.000061
# A.2_pfail                5.812201e-02  0.014175
# A.3_Bmax                 1.421365e-04  0.000138
# A.3_Brate                3.061094e-06  0.000003
# A.3_pfail                3.863032e-01  0.075887
# A.4_Bmax                 1.962122e-05  0.000021
# A.4_Brate                9.498754e-07  0.000001
# A.4_pfail                4.342407e-03  0.001156
# A.5_Bmax                 0.000000e+00  0.000000
# A.5_Brate                0.000000e+00  0.000000
# A.5_pfail                6.907861e-02  0.019287
# discount rate 0          9.732310e-03  0.002336
# discount rate 1          1.085956e-02  0.002629
# discount rate 2          1.085622e-02  0.002997
#                                S1   S1_conf
# A.0_ID flood wave shape  0.010417  0.012897
# A.1_Bmax                -0.000271  0.001272
# A.1_Brate                0.000060  0.000339
# A.1_pfail                0.421080  0.146207
# A.2_Bmax                -0.001619  0.002246
# A.2_Brate               -0.000162  0.000555
# A.2_pfail                0.048484  0.025873
# A.3_Bmax                -0.000387  0.000854
# A.3_Brate                0.000150  0.000199
# A.3_pfail                0.365215  0.088998
# A.4_Bmax                -0.000028  0.000206
# A.4_Brate                0.000023  0.000047
# A.4_pfail               -0.000567  0.005016
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.054395  0.032397
# discount rate 0          0.002000  0.007422
# discount rate 1          0.007031  0.009648
# discount rate 2          0.002935  0.006919
#                                             S2   S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)  -0.009136  0.015280
# (A.0_ID flood wave shape, A.1_Brate) -0.008989  0.015263
# (A.0_ID flood wave shape, A.1_pfail) -0.012981  0.020891
# (A.0_ID flood wave shape, A.2_Bmax)  -0.008756  0.015257
# (A.0_ID flood wave shape, A.2_Brate) -0.009008  0.015257
# ...                                        ...       ...
# (A.5_pfail, discount rate 1)          0.000263  0.038201
# (A.5_pfail, discount rate 2)          0.000234  0.038916
# (discount rate 0, discount rate 1)    0.002710  0.014597
# (discount rate 0, discount rate 2)    0.003247  0.013733
# (discount rate 1, discount rate 2)   -0.008941  0.015839
#
# [171 rows x 2 columns]
#                           ST  ST_conf
# A.0_ID flood wave shape  0.0      NaN
# A.1_Bmax                 0.0      NaN
# A.1_Brate                0.0      NaN
# A.1_pfail                0.0      NaN
# A.2_Bmax                 0.0      NaN
# A.2_Brate                0.0      NaN
# A.2_pfail                0.0      NaN
# A.3_Bmax                 0.0      NaN
# A.3_Brate                0.0      NaN
# A.3_pfail                0.0      NaN
# A.4_Bmax                 0.0      NaN
# A.4_Brate                0.0      NaN
# A.4_pfail                0.0      NaN
# A.5_Bmax                 0.0      NaN
# A.5_Brate                0.0      NaN
# A.5_pfail                0.0      NaN
# discount rate 0          0.0      NaN
# discount rate 1          0.0      NaN
# discount rate 2          0.0      NaN
#                           S1  S1_conf
# A.0_ID flood wave shape  0.0      NaN
# A.1_Bmax                 0.0      NaN
# A.1_Brate                0.0      NaN
# A.1_pfail                0.0      NaN
# A.2_Bmax                 0.0      NaN
# A.2_Brate                0.0      NaN
# A.2_pfail                0.0      NaN
# A.3_Bmax                 0.0      NaN
# A.3_Brate                0.0      NaN
# A.3_pfail                0.0      NaN
# A.4_Bmax                 0.0      NaN
# A.4_Brate                0.0      NaN
# A.4_pfail                0.0      NaN
# A.5_Bmax                 0.0      NaN
# A.5_Brate                0.0      NaN
# A.5_pfail                0.0      NaN
# discount rate 0          0.0      NaN
# discount rate 1          0.0      NaN
# discount rate 2          0.0      NaN
#                                        S2  S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)   0.0      NaN
# (A.0_ID flood wave shape, A.1_Brate)  0.0      NaN
# (A.0_ID flood wave shape, A.1_pfail)  0.0      NaN
# (A.0_ID flood wave shape, A.2_Bmax)   0.0      NaN
# (A.0_ID flood wave shape, A.2_Brate)  0.0      NaN
# ...                                   ...      ...
# (A.5_pfail, discount rate 1)          0.0      NaN
# (A.5_pfail, discount rate 2)          0.0      NaN
# (discount rate 0, discount rate 1)    0.0      NaN
# (discount rate 0, discount rate 2)    0.0      NaN
# (discount rate 1, discount rate 2)    0.0      NaN
#
# [171 rows x 2 columns]
# C:\Users\admin\Documents\GitHub\MBDM_Group5\venv\Lib\site-packages\SALib\analyze\sobol.py:129: RuntimeWarning: invalid value encountered in divide
#   Y = (Y - Y.mean()) / Y.std()
#                          ST  ST_conf
# A.0_ID flood wave shape NaN      NaN
# A.1_Bmax                NaN      NaN
# A.1_Brate               NaN      NaN
# A.1_pfail               NaN      NaN
# A.2_Bmax                NaN      NaN
# A.2_Brate               NaN      NaN
# A.2_pfail               NaN      NaN
# A.3_Bmax                NaN      NaN
# A.3_Brate               NaN      NaN
# A.3_pfail               NaN      NaN
# A.4_Bmax                NaN      NaN
# A.4_Brate               NaN      NaN
# A.4_pfail               NaN      NaN
# A.5_Bmax                NaN      NaN
# A.5_Brate               NaN      NaN
# A.5_pfail               NaN      NaN
# discount rate 0         NaN      NaN
# discount rate 1         NaN      NaN
# discount rate 2         NaN      NaN
#                          S1  S1_conf
# A.0_ID flood wave shape NaN      NaN
# A.1_Bmax                NaN      NaN
# A.1_Brate               NaN      NaN
# A.1_pfail               NaN      NaN
# A.2_Bmax                NaN      NaN
# A.2_Brate               NaN      NaN
# A.2_pfail               NaN      NaN
# A.3_Bmax                NaN      NaN
# A.3_Brate               NaN      NaN
# A.3_pfail               NaN      NaN
# A.4_Bmax                NaN      NaN
# A.4_Brate               NaN      NaN
# A.4_pfail               NaN      NaN
# A.5_Bmax                NaN      NaN
# A.5_Brate               NaN      NaN
# A.5_pfail               NaN      NaN
# discount rate 0         NaN      NaN
# discount rate 1         NaN      NaN
# discount rate 2         NaN      NaN
#                                       S2  S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)  NaN      NaN
# (A.0_ID flood wave shape, A.1_Brate) NaN      NaN
# (A.0_ID flood wave shape, A.1_pfail) NaN      NaN
# (A.0_ID flood wave shape, A.2_Bmax)  NaN      NaN
# (A.0_ID flood wave shape, A.2_Brate) NaN      NaN
# ...                                   ..      ...
# (A.5_pfail, discount rate 1)         NaN      NaN
# (A.5_pfail, discount rate 2)         NaN      NaN
# (discount rate 0, discount rate 1)   NaN      NaN
# (discount rate 0, discount rate 2)   NaN      NaN
# (discount rate 1, discount rate 2)   NaN      NaN
#
# [171 rows x 2 columns]
#                                ST   ST_conf
# A.0_ID flood wave shape  0.014637  0.003907
# A.1_Bmax                 0.009504  0.014084
# A.1_Brate                0.000080  0.000115
# A.1_pfail                0.027009  0.010141
# A.2_Bmax                 0.006760  0.010987
# A.2_Brate                0.000096  0.000153
# A.2_pfail                0.130088  0.026086
# A.3_Bmax                 0.000501  0.000479
# A.3_Brate                0.000010  0.000012
# A.3_pfail                0.650626  0.059980
# A.4_Bmax                 0.000054  0.000056
# A.4_Brate                0.000004  0.000006
# A.4_pfail                0.014548  0.003469
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.208344  0.050435
# discount rate 0          0.000000  0.000000
# discount rate 1          0.000000  0.000000
# discount rate 2          0.000000  0.000000
#                                S1   S1_conf
# A.0_ID flood wave shape  0.010671  0.012252
# A.1_Bmax                -0.001345  0.002687
# A.1_Brate               -0.000001  0.000552
# A.1_pfail                0.005983  0.015945
# A.2_Bmax                -0.003502  0.004747
# A.2_Brate               -0.000164  0.001354
# A.2_pfail                0.108408  0.043290
# A.3_Bmax                -0.000699  0.001527
# A.3_Brate                0.000180  0.000222
# A.3_pfail                0.631467  0.125488
# A.4_Bmax                -0.000017  0.000335
# A.4_Brate                0.000060  0.000108
# A.4_pfail               -0.002030  0.010389
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.184046  0.071049
# discount rate 0          0.000000  0.000000
# discount rate 1          0.000000  0.000000
# discount rate 2          0.000000  0.000000
#                                             S2   S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)  -0.010092  0.018129
# (A.0_ID flood wave shape, A.1_Brate) -0.009856  0.018138
# (A.0_ID flood wave shape, A.1_pfail) -0.010574  0.018087
# (A.0_ID flood wave shape, A.2_Bmax)  -0.009301  0.018026
# (A.0_ID flood wave shape, A.2_Brate) -0.009904  0.018156
# ...                                        ...       ...
# (A.5_pfail, discount rate 1)         -0.014351  0.093049
# (A.5_pfail, discount rate 2)         -0.014351  0.093049
# (discount rate 0, discount rate 1)    0.000000  0.000000
# (discount rate 0, discount rate 2)    0.000000  0.000000
# (discount rate 1, discount rate 2)    0.000000  0.000000
#
# [171 rows x 2 columns]
#                                    ST   ST_conf
# A.0_ID flood wave shape  9.512788e-03  0.003330
# A.1_Bmax                 9.829066e-03  0.014302
# A.1_Brate                2.853608e-05  0.000027
# A.1_pfail                1.307764e-01  0.041228
# A.2_Bmax                 6.694249e-03  0.012314
# A.2_Brate                1.972449e-05  0.000032
# A.2_pfail                2.962595e-02  0.007481
# A.3_Bmax                 9.837722e-05  0.000082
# A.3_Brate                1.782661e-06  0.000003
# A.3_pfail                7.959085e-01  0.073086
# A.4_Bmax                 1.170156e-05  0.000010
# A.4_Brate                8.707390e-07  0.000001
# A.4_pfail                1.709916e-03  0.000656
# A.5_Bmax                 0.000000e+00  0.000000
# A.5_Brate                0.000000e+00  0.000000
# A.5_pfail                3.997047e-02  0.009817
# discount rate 0          0.000000e+00  0.000000
# discount rate 1          0.000000e+00  0.000000
# discount rate 2          0.000000e+00  0.000000
#                                S1   S1_conf
# A.0_ID flood wave shape  0.012528  0.013212
# A.1_Bmax                 0.000014  0.001986
# A.1_Brate                0.000170  0.000449
# A.1_pfail                0.108685  0.058269
# A.2_Bmax                -0.002728  0.004282
# A.2_Brate               -0.000203  0.000440
# A.2_pfail                0.019758  0.014812
# A.3_Bmax                -0.000203  0.000684
# A.3_Brate                0.000084  0.000132
# A.3_pfail                0.779141  0.147463
# A.4_Bmax                -0.000049  0.000181
# A.4_Brate                0.000026  0.000047
# A.4_pfail               -0.002113  0.004991
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.030983  0.016874
# discount rate 0          0.000000  0.000000
# discount rate 1          0.000000  0.000000
# discount rate 2          0.000000  0.000000
#                                             S2   S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)  -0.012851  0.019274
# (A.0_ID flood wave shape, A.1_Brate) -0.012717  0.019285
# (A.0_ID flood wave shape, A.1_pfail) -0.014118  0.020191
# (A.0_ID flood wave shape, A.2_Bmax)  -0.012367  0.019283
# (A.0_ID flood wave shape, A.2_Brate) -0.012743  0.019290
# ...                                        ...       ...
# (A.5_pfail, discount rate 1)          0.001005  0.022925
# (A.5_pfail, discount rate 2)          0.001005  0.022925
# (discount rate 0, discount rate 1)    0.000000  0.000000
# (discount rate 0, discount rate 2)    0.000000  0.000000
# (discount rate 1, discount rate 2)    0.000000  0.000000
#
# [171 rows x 2 columns]
#                                    ST       ST_conf
# A.0_ID flood wave shape  1.002416e+00  6.302951e-02
# A.1_Bmax                 1.343604e-03  2.778859e-03
# A.1_Brate                1.385809e-14  2.038762e-14
# A.1_pfail                1.895689e-03  3.750664e-03
# A.2_Bmax                 9.989162e-03  7.916472e-03
# A.2_Brate                7.987239e-07  1.549084e-06
# A.2_pfail                2.532602e-02  2.243357e-02
# A.3_Bmax                 1.537065e-03  1.696979e-03
# A.3_Brate                1.450019e-05  2.882539e-05
# A.3_pfail                1.399495e-02  1.570523e-02
# A.4_Bmax                 3.705706e-02  2.903189e-02
# A.4_Brate                1.676464e-03  2.119040e-03
# A.4_pfail                3.890894e-02  3.348296e-02
# A.5_Bmax                 0.000000e+00  0.000000e+00
# A.5_Brate                0.000000e+00  0.000000e+00
# A.5_pfail                0.000000e+00  0.000000e+00
# discount rate 0          0.000000e+00  0.000000e+00
# discount rate 1          0.000000e+00  0.000000e+00
# discount rate 2          0.000000e+00  0.000000e+00
#                                    S1       S1_conf
# A.0_ID flood wave shape  9.545969e-01  1.504627e-01
# A.1_Bmax                 1.192990e-04  1.752301e-03
# A.1_Brate               -1.462112e-08  2.627936e-08
# A.1_pfail                1.698249e-04  1.939097e-03
# A.2_Bmax                -2.002149e-03  9.676117e-03
# A.2_Brate               -1.349566e-05  2.618107e-05
# A.2_pfail                3.803536e-04  4.835103e-03
# A.3_Bmax                 7.424903e-04  1.195599e-03
# A.3_Brate               -5.746250e-05  1.143930e-04
# A.3_pfail               -2.944161e-04  3.915180e-03
# A.4_Bmax                 1.230116e-02  2.153648e-02
# A.4_Brate               -3.441645e-04  1.114076e-03
# A.4_pfail                2.153602e-03  2.935148e-02
# A.5_Bmax                 0.000000e+00  0.000000e+00
# A.5_Brate                0.000000e+00  0.000000e+00
# A.5_pfail                0.000000e+00  0.000000e+00
# discount rate 0          0.000000e+00  0.000000e+00
# discount rate 1          0.000000e+00  0.000000e+00
# discount rate 2          0.000000e+00  0.000000e+00
#                                             S2   S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)   0.017707  0.309694
# (A.0_ID flood wave shape, A.1_Brate)  0.009404  0.309071
# (A.0_ID flood wave shape, A.1_pfail)  0.016921  0.309308
# (A.0_ID flood wave shape, A.2_Bmax)   0.003455  0.306879
# (A.0_ID flood wave shape, A.2_Brate)  0.009651  0.309210
# ...                                        ...       ...
# (A.5_pfail, discount rate 1)          0.000000  0.000000
# (A.5_pfail, discount rate 2)          0.000000  0.000000
# (discount rate 0, discount rate 1)    0.000000  0.000000
# (discount rate 0, discount rate 2)    0.000000  0.000000
# (discount rate 1, discount rate 2)    0.000000  0.000000
#
# [171 rows x 2 columns]
#                                ST   ST_conf
# A.0_ID flood wave shape  0.988655  0.061176
# A.1_Bmax                 0.000000  0.000000
# A.1_Brate                0.000000  0.000000
# A.1_pfail                0.000000  0.000000
# A.2_Bmax                 0.000000  0.000000
# A.2_Brate                0.000000  0.000000
# A.2_pfail                0.000000  0.000000
# A.3_Bmax                 0.000000  0.000000
# A.3_Brate                0.000000  0.000000
# A.3_pfail                0.000000  0.000000
# A.4_Bmax                 0.000000  0.000000
# A.4_Brate                0.000000  0.000000
# A.4_pfail                0.000000  0.000000
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.000000  0.000000
# discount rate 0          0.000000  0.000000
# discount rate 1          0.000000  0.000000
# discount rate 2          0.000000  0.000000
#                                S1   S1_conf
# A.0_ID flood wave shape  0.979354  0.131207
# A.1_Bmax                 0.000000  0.000000
# A.1_Brate                0.000000  0.000000
# A.1_pfail                0.000000  0.000000
# A.2_Bmax                 0.000000  0.000000
# A.2_Brate                0.000000  0.000000
# A.2_pfail                0.000000  0.000000
# A.3_Bmax                 0.000000  0.000000
# A.3_Brate                0.000000  0.000000
# A.3_pfail                0.000000  0.000000
# A.4_Bmax                 0.000000  0.000000
# A.4_Brate                0.000000  0.000000
# A.4_pfail                0.000000  0.000000
# A.5_Bmax                 0.000000  0.000000
# A.5_Brate                0.000000  0.000000
# A.5_pfail                0.000000  0.000000
# discount rate 0          0.000000  0.000000
# discount rate 1          0.000000  0.000000
# discount rate 2          0.000000  0.000000
#                                             S2   S2_conf
# (A.0_ID flood wave shape, A.1_Bmax)   0.018602  0.254674
# (A.0_ID flood wave shape, A.1_Brate)  0.018602  0.254674
# (A.0_ID flood wave shape, A.1_pfail)  0.018602  0.254674
# (A.0_ID flood wave shape, A.2_Bmax)   0.018602  0.254674
# (A.0_ID flood wave shape, A.2_Brate)  0.018602  0.254674
# ...                                        ...       ...
# (A.5_pfail, discount rate 1)          0.000000  0.000000
# (A.5_pfail, discount rate 2)          0.000000  0.000000
# (discount rate 0, discount rate 1)    0.000000  0.000000
# (discount rate 0, discount rate 2)    0.000000  0.000000
# (discount rate 1, discount rate 2)    0.000000  0.000000
#
# [171 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

Si_filter=dict()

for item in ['Expected Annual Damage', 'Expected Number of Deaths', 'Min Water Level']:
    Si_filter[item] = {k:results_Si[item][k] for k in ['ST','ST_conf','S1','S1_conf']}
    Si_df = pd.DataFrame(Si_filter[item], index=problem['names'])

    sns.set_style('white')
    fig, ax = plt.subplots(1)

    indices = Si_df[['S1','ST']]
    err = Si_df[['S1_conf','ST_conf']]

    indices.plot.bar(yerr=err.values.T,ax=ax)
    fig.set_size_inches(8,6)
    fig.subplots_adjust(bottom=0.3)
    plt.savefig(f"Final GSA policy 1412_{item}")
    plt.ylabel(f"{item}")
    plt.show()

# %%
print(outcome_names)
# Out:
# ['Expected Annual Damage', 'Dike Investment Costs', 'RfR Investment Costs', 'Evacuation Costs', 'Expected Number of Deaths', 'Min Water Level', 'Max Water Level']
